# %% [markdown]
# # Filtre, descarte valores nulos, desduplique
# Use os arquivos `data_08.csv` e `data_18.csv`

# %%
# carregue conjuntos de dados
import pandas as pd
df_08 = pd.read_csv('data/data_08.csv')
df_18 = pd.read_csv('data/data_18.csv')

# %%
# exiba as dimensões do conjunto de dados
df_08.shape
# Out:
# (2404, 14)

# %%
# exiba as dimensões do conjunto de dados
df_18.shape
# Out:
# (1611, 14)

# %% [markdown]
# ## Filtre por região de certificação

# %%
df_08.query('cert_region == "CA"')
# Out:
#                          model  displ       cyl    trans drive      fuel  \
# 0                    ACURA MDX    3.7   (6 cyl)  Auto-S5   4WD  Gasoline
# 2                    ACURA RDX    2.3   (4 cyl)  Auto-S5   4WD  Gasoline
# 4                     ACURA RL    3.5   (6 cyl)  Auto-S5   4WD  Gasoline
# 6                     ACURA TL    3.2   (6 cyl)  Auto-S5   2WD  Gasoline
# 7                     ACURA TL    3.5   (6 cyl)  Auto-S5   2WD  Gasoline
# 8                     ACURA TL    3.5   (6 cyl)    Man-6   2WD  Gasoline
# 14                   ACURA TSX    2.4   (4 cyl)    Man-6   2WD  Gasoline
# 15                   ACURA TSX    2.4   (4 cyl)  Auto-S5   2WD  Gasoline
# 18            ASTON MARTIN DB9    5.9  (12 cyl)    Man-6   2WD  Gasoline
# 19            ASTON MARTIN DB9    5.9  (12 cyl)  Auto-S6   2WD  Gasoline
# 22    ASTON MARTIN DB9 Volante    5.9  (12 cyl)    Man-6   2WD  Gasoline
# 23    ASTON MARTIN DB9 Volante    5.9  (12 cyl)  Auto-S6   2WD  Gasoline
# 26     ASTON MARTIN V8 Vantage    4.3   (8 cyl)    Man-6   2WD  Gasoline
# 27     ASTON MARTIN V8 Vantage    4.3   (8 cyl)  Auto-S6   2WD  Gasoline
# 28                     AUDI A3    2.0   (4 cyl)    Man-6   2WD  Gasoline
# 29                     AUDI A3    2.0   (4 cyl)  Auto-S6   2WD  Gasoline
# 33                     AUDI A3    3.2   (6 cyl)  Auto-S6   4WD  Gasoline
# 34                     AUDI A4    2.0   (4 cyl)  Auto-AV   2WD  Gasoline
# 39                     AUDI A4    3.1   (6 cyl)    Man-6   4WD  Gasoline
# 40                     AUDI A4    3.1   (6 cyl)  Auto-S6   4WD  Gasoline
# 41                     AUDI A4    3.1   (6 cyl)  Auto-AV   2WD  Gasoline
# 44               AUDI A4 Avant    3.1   (6 cyl)    Man-6   4WD  Gasoline
# 45               AUDI A4 Avant    3.1   (6 cyl)  Auto-S6   4WD  Gasoline
# 47           AUDI A4 Cabriolet    3.1   (6 cyl)  Auto-S6   4WD  Gasoline
# 50                     AUDI A6    3.1   (6 cyl)  Auto-S6   4WD  Gasoline
# 51                     AUDI A6    3.1   (6 cyl)  Auto-AV   2WD  Gasoline
# 53                     AUDI A6    4.2   (8 cyl)  Auto-S6   4WD  Gasoline
# 55               AUDI A6 Avant    3.1   (6 cyl)  Auto-S6   4WD  Gasoline
# 57                     AUDI A8    4.2   (8 cyl)  Auto-S6   4WD  Gasoline
# 8             CA    midsize car                   7       18      27      21
# 14            CA      small car                   6       19      28      22
# 15            CA      small car                   6       20      28      23
# 18            CA      small car                   6       10      16      12
# 19            CA      small car                   6       11      18      13
# 22            CA      small car                   6       10      16      12
# 23            CA      small car                   6       11      17      13
# 26            CA      small car                   6       12      19      15
# 27            CA      small car                   6       13      20      15
# 28            CA  station wagon                   7       21      29      24
# 29            CA  station wagon                   7       22      29      25
# 33            CA  station wagon                   6       18      25      21
# 34            CA      small car                   7       21      30      24
# 39            CA      small car                   6       15      25      19
# 40            CA      small car                   6       17      25      20
# 41            CA      small car                   6       18      27      21
# 44            CA  station wagon                   6       15      25      19
# 45            CA  station wagon                   6       17      25      20
# 47            CA      small car                   6       17      25      20
# 50            CA    midsize car                   6       17      25      20
# 51            CA    midsize car                   6       18      27      21
# 53            CA    midsize car                   6       16      23      18
# 55            CA  station wagon                   6       17      25      20
# 57            CA    midsize car                   6       16      23      18
# 59            CA      large car                   6       16      23      18
# ...          ...            ...                 ...      ...     ...     ...
# 2345          CA      small car                   7       18      27      21
# 2348          CA      small car                 9.5       20      28      23
# 2349          CA      small car                   7       20      28      23
# 2350          CA      small car                   7       20      28      23
# 2351          CA      small car                   7       17      25      20
# 2352          CA      small car                   7       18      26      21
# 2353          CA      small car                   7       19      27      22
# 2354          CA      small car                   7       19      28      23
# 2361          CA      small car                   7       17      26      21
# 2362          CA      small car                   7       18      26      21
# 2363          CA      small car                   7       19      27      22
# 2364          CA      small car                   7       19      27      22
# 2367          CA      small car                   6       18      26      21
# 2368          CA      small car                   6       18      26      21
# 2373          CA    midsize car                   7       15      23      18
# 2374          CA    midsize car                   7       16      24      19
# 2375          CA    midsize car                   7       16      24      19
# 2376          CA    midsize car                   7       15      23      18
# 2381          CA  station wagon                 9.5       20      28      23
# 2382          CA  station wagon                   7       20      28      23
# 2383          CA  station wagon                   7       20      28      23
# 2384          CA  station wagon                   7       17      25      20
# 2385          CA  station wagon                   7       18      26      21
# 2386          CA  station wagon                   7       19      27      22
# 2387          CA  station wagon                   7       19      28      23
# 2394          CA  station wagon                   7       16      24      19
# 2396          CA            SUV                   7       15      22      17
# 2398          CA            SUV                   7       14      20      16
# 2399          CA            SUV                   7       14      20      16
# 2400          CA            SUV                   7       13      19      15
#
#      greenhouse_gas_score smartway
# 0                       4       no
# 2                       5       no
# 4                       5       no
# 6                       6      yes
# 7                       6      yes
# 8                       6      yes
# 14                      6       no
# 15                      7      yes
# 18                      0       no
# 19                      1       no
# 22                      0       no
# 23                      1       no
# 26                      3       no
# 27                      3       no
# 28                      7      yes
# 29                      7      yes
# 33                      6       no
# 34                      7      yes
# 39                      5       no
# 40                      6       no
# 41                      6       no
# 44                      5       no
# 45                      6       no
# 47                      6       no
# 50                      6       no
# 51                      6       no
# 53                      5       no
# 55                      6       no
# 57                      5       no
# 59                      5       no
# ...                   ...      ...
# 2345                    6      yes
# 2348                    7      yes
# 2349                    7      yes
# 2350                    7      yes
# 2351                    6      yes
# 2352                    6      yes
# 2353                    6      yes
# 2354                    7      yes
# 2361                    6      yes
# 2362                    6      yes
# 2363                    6      yes
# 2364                    6      yes
# 2367                    6       no
# 2368                    6       no
# 2373                    5       no
# 2374                    5       no
# 2375                    5       no
# 2376                    5       no
# 2381                    7      yes
# 2382                    7      yes
# 2383                    7      yes
# 2384                    6      yes
# 2385                    6      yes
# 2386                    6      yes
# 2387                    7      yes
# 2394                    5       no
# 2396                    4       no
# 2398                    4       no
# 2399                    4       no
# 2400                    3       no
#
# [1084 rows x 14 columns]

# %%
# filtre conjuntos de dados por linhas segundo os padrões da Califórnia
df_08 = df_08.query("cert_region == 'CA'")
df_18 = df_18.query("cert_region == 'CA'")

# %%
# confirme que a única região de certificação é a Califórnia
df_08['cert_region'].unique()
# Out:
# array(['CA'], dtype=object)

# %%
# confirme que a única região de certificação é a Califórnia
df_18['cert_region'].unique()
# Out:
# array(['CA'], dtype=object)

# %%
# descarte a coluna de certificação de região de ambos conjuntos de dados
df_08.drop('cert_region', axis=1, inplace=True)
df_18.drop('cert_region', axis=1, inplace=True)

# %%
df_08.shape
# Out:
# (1084, 13)

# %%
df_18.shape
# Out:
# (798, 13)

# %% [markdown]
# ## Descarte linhas com valores faltantes

# %%
# exiba a contagem de valores faltantes para cada característica em 2008
df_08.isnull().sum()
# Out:
# model                    0
# displ                    0
# cyl                     75
# trans                   75
# drive                   37
# fuel                     0
# veh_class                0
# air_pollution_score      0
# city_mpg                75
# hwy_mpg                 75
# cmb_mpg                 75
# greenhouse_gas_score    75
# smartway                 0
# dtype: int64

# %%
# exiba a contagem de valores faltantes para cada característica em 2018
df_18.isnull().sum()
# Out:
# model                   0
# displ                   1
# cyl                     1
# trans                   0
# drive                   0
# fuel                    0
# veh_class               0
# air_pollution_score     0
# city_mpg                0
# hwy_mpg                 0
# cmb_mpg                 0
# greenhouse_gas_score    0
# smartway                0
# dtype: int64

# %%
# descarte linhas com quaisquer valores nulos em ambos conjuntos de dados
df_08.dropna(axis=0, how='any', inplace=True)
df_08.shape
# Out:
# (1009, 13)

# %%
df_18.dropna(axis=0, how='any', inplace=True)
df_18.shape
# Out:
# (797, 13)

# %%
# verifique se quaisquer colunas em 2008 têm valores nulos - o resultado deve ser False
df_08.isnull().sum().any()
# Out:
# False

# %%
# verifique se quaisquer colunas em 2018 têm valores nulos - o resultado deve ser False
df_18.isnull().sum().any()
# Out:
# False

# %% [markdown]
# ## Desduplique os dados

# %%
# exiba o número de duplicatas nos conjuntos de dados de 2008 e 2018
df_08.duplicated().sum()
# Out:
# 23

# %%
df_18.duplicated().sum()
# Out:
# 3

# %%
# descarte duplicatas em ambos conjuntos de dados
df_08.drop_duplicates(keep='first', inplace=True)
df_18.drop_duplicates(keep='first', inplace=True)

# %%
# exiba o número de duplicatas novamente para confirmar desduplicação - ambos devem ser 0
print('08: ', df_08.duplicated().sum())
print('18: ', df_18.duplicated().sum())
# Out:
# 08:  0
# 18:  0

# %%
# salve seu progresso para a próxima seção
df_08.to_csv('data/data_08.csv', index=False)
df_18.to_csv('data/data_18.csv', index=False)
